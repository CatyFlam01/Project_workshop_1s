# %% [markdown]
# # Базовые модели

# %% [markdown]
# ## Обучение базовых моделей (Linear Regression, Decision Tree, Random Forest). Оценка по кросс-валидации.

# %% [markdown]
# ## Интерпретация результатов, анализ важности признаков, ошибок модели
