# %% [markdown]
# # Финализация модели

# %% [markdown]
# ## Обучение финальной модели на всем тренировочном датасете, создание итоговых предсказаний

# %% [markdown]
# ## Оформление EDA, хода исследования, выводов в итоговый отчет
